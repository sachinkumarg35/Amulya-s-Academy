# %%
#Program to calculate LCM of two numbers.

# %%
def Compute_LCM(n1, n2):
    if n1>n2:
        higher = n1
    else:
        higher = n2
    value = higher
    while True:
        if higher%n1==0 and higher%n2==0:
            print("LCM of", n1, "and", n2, "is", higher)
            break
        else:
            higher = higher+value
            
n1 = int(input("Enter the first number: "))
n2 = int(input("Enter the second number: "))
Compute_LCM(n1,n2)
# Out:
# Enter the first number: 12
# Enter the second number: 18
# LCM of 12 and 18 is 36

# %%
#Program to calculate LCM using GCD | Relation b/w GCD and LCM |

# %%
def Compute_GCD(a,b):
    if b==0:
        return a
    else:
        return Compute_GCD(b, a%b)
    
n1 = int(input("Enter the first number: "))
n2 = int(input("Enter the second number: "))
LCM = (n1*n2)//Compute_GCD(n1,n2)
print(LCM)
# Out:
# Enter the first number: 4
# Enter the second number: 6
# 12

# %%
#To add text to the plot | Text function in matplotlib

# %%
import matplotlib.pyplot as plt
plt.plot([10,20,30,40], marker = 'o')
ax = plt.gca()
plt.text(0,0, 'NOTE', transform = ax.transAxes)
print(plt.ylim())
plt.show()
# Out:
# (8.5, 41.5)

# %%
#Introduction to data structures.

# %%
#BuiltIn data structures
#1. List
#2. Tuple
#3. Set
#4. Dictionary

# %%
#User Defined data structures.
#1. Stack
#2. Queue
#3. Linked list
#4. Tree
#5. Graph

# %%
#To add Annotation to the plot | Annotate function in matplotlib

# %%
import matplotlib.pyplot as plt

plt.plot([10,20,30,40], marker='o')
plt.annotate("point", (1,20), size=20, color = 'red', arrowprops={"arrowstyle":"<-"})

plt.show()

# %%
#To add box around the text in the plot | bbox keyword argument.

# %%
import matplotlib.pyplot as plt

plt.plot([10,20,30,40], marker='o')
plt.text(1,20, "point", bbox={"fc":"green", 'boxstyle':'larrow'})
plt.text(2,30, "this is the point to add", bbox={'fc':'red','boxstyle':'darrow'})

plt.show()

# %%
#Types of plot 
#1.

# %%
#Line plot
import matplotlib.pyplot as plt

year = [2001,2002,2003,2004,2005,2006,2007,2008,2009,2010]
Unemployment = [9.8, 12, 8, 7.7, 6.8, 7, 6.8,6.2, 5.4, 6.2]

plt.plot(year, Unemployment, marker='*', linestyle="-.")
plt.xlabel("year")
plt.ylabel("Unemployment")
plt.title("year v/s Unemployment rate")

plt.show()

# %%
#Bar grapgh | Bar Chart | Matplotlib

# %%
import matplotlib.pyplot as plt
x = ['CSE', 'ISE', 'EE', 'EC', 'MECH']
y = ['100', '60', '90', '80', '150']
c = ['red', 'green', 'blue', 'black', 'yellow']
w = [0.4, 0.5, 0.6, 0.8, 0.6]
plt.bar(x, y, width=w, color=c)
plt.xlabel("Engineering Courses")
plt.ylabel('Students enrolled')
plt.title("Students enrolled for different courses.")
plt.show()

# %%
import matplotlib.pyplot as plt
y = ["science", "commerce", "arts"]
w = [200, 300, 500]
c = ['red', 'green', 'orange']
plt.barh(y, w, color=c, left=[20,30,40])
plt.xlabel("Courses")
plt.ylabel("Students enrolled")
plt.title("Students enrolled for different cousres")
plt.show()

# %%
#Implementing stack using list | Data structures

# %%
stack = []
def push():
    element = input("Enter the element: ")
    stack.append(element)
    print(stack)
    
def pop_element():
    if not stack:
        print("stack is empty")
    else:
        e = stack.pop()
        print("removed element.", e)
        print(stack)
        
while True:
    print("Select the operation 1. push 2. pop 3. quit")
    choice = int(input())
    if choice == 1:
        push()
    elif choice == 2:
        pop_element()
    elif choice == 3:
        break
    else:
        print("Enter the correct operation.")
# Out:
# Select the operation 1. push 2. pop 3. quit
# 1
# Enter the element: 10
# ['10']
# Select the operation 1. push 2. pop 3. quit
# 1
# Enter the element: 20
# ['10', '20']
# Select the operation 1. push 2. pop 3. quit
# 1
# Enter the element: 30
# ['10', '20', '30']
# Select the operation 1. push 2. pop 3. quit
# 2
# removed element. 30
# ['10', '20']
# Select the operation 1. push 2. pop 3. quit
# 3

# %%
stack = []
def push():
    if len(stack)==n:
        print("list is full")
    else:
        element = input("Enter the element: ")
        stack.append(element)
        print(stack)
    
def pop_element():
    if not stack:
        print("stack is empty")
    else:
        e = stack.pop()
        print("removed element.", e)
        print(stack)

n = int(input("Limit of stack"))
while True:
    print("Select the operation 1. push 2. pop 3. quit")
    choice = int(input())
    if choice == 1:
        push()
    elif choice == 2:
        pop_element()
    elif choice == 3:
        break
    else:
        print("Enter the correct operation.")
# Out:
# Limit of stack5
# Select the operation 1. push 2. pop 3. quit
# 1
# Enter the element: 10
# ['10']
# Select the operation 1. push 2. pop 3. quit
# 1
# Enter the element: 20
# ['10', '20']
# Select the operation 1. push 2. pop 3. quit
# 1
# Enter the element: 30
# ['10', '20', '30']
# Select the operation 1. push 2. pop 3. quit
# 1
# Enter the element: 40
# ['10', '20', '30', '40']
# Select the operation 1. push 2. pop 3. quit
# 1
# Enter the element: 50
# ['10', '20', '30', '40', '50']
# Select the operation 1. push 2. pop 3. quit
# 1
# list is full
# Select the operation 1. push 2. pop 3. quit
# 2
# removed element. 50
# ['10', '20', '30', '40']
# Select the operation 1. push 2. pop 3. quit
# 2
# removed element. 40
# ['10', '20', '30']
# Select the operation 1. push 2. pop 3. quit
# 3

# %%
#Implementing stack using modules

# %%
#Collections module

# %%
import collections

# %%
stack = collections.deque()
stack
# Out:
# deque([])

# %%
stack.append(10)

# %%
stack.append(30)

# %%
stack.append(60)

# %%
stack
# Out:
# deque([10, 30, 60])

# %%
stack.pop()
# Out:
# 60

# %%
stack.pop()
# Out:
# 30

# %%
stack.pop()
# Out:
# 10

# %%
stack.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-415460d3b717> in <module>
# ----> 1 stack.pop()
#
# IndexError: pop from an empty deque

# %%
not stack
# Out:
# True

# %%
stack.append(80)

# %%
stack.append(100)

# %%
stack[-1]
# Out:
# 100

# %%
#Queue module

# %%
import queue

# %%
stack = queue.LifoQueue()

# %%
stack.put(25)

# %%
stack.put(35)

# %%
stack.put(45)

# %%
stack.get()
# Out:
# 45

# %%
stack.get()
# Out:
# 35

# %%
stack.get()
# Out:
# 25

# %%
#Stacked bargraph

# %%
import matplotlib.pyplot as plt
import numpy as np
x = ['USA', 'Russia', 'GBR', 'China', 'Germany']

gold = [20,10,5,23,32]
silver = [100, 45, 25, 120, 95]
bronze = [200, 150, 100, 230, 280]

b_bronze = list(np.add(gold, silver))

plt.bar(x, gold, 0.5, label='Gold')
plt.bar(x, silver, 0.5, bottom = gold, label = 'Silver')
plt.bar(x, bronze, 0.5, bottom=b_bronze, label = 'Bronze')

plt.xlabel("COuntries")
plt.ylabel("Medals")
plt.title("Medal v/s Countries")
plt.legend()
plt.show()

# %%
#Multiple bar graph | Grouped graph

# %%
import matplotlib.pyplot as plt
import numpy as np
w=0.4
x = ["CSE", "ISE", "ECE", "EEE", "Mech"]
boys = [100, 40, 60, 240, 300]
girls = [200, 70, 30, 100, 15]

bar1 = np.arange(len(x))
bar2 = [i+w for i in bar1]

plt.bar(bar1, boys, w, label="boys")
plt.bar(bar2, girls, w, label="girls")

plt.xlabel("Courses")
plt.ylabel("Students")
plt.title("Students v/s Courses")
plt.xticks(bar1+w/2, x)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = ['USA', 'Russia', 'GBR', 'China', 'Germany']
w=0.2 

gold = [20,10,5,23,32]
silver = [100, 45, 25, 120, 95]
bronze = [200, 150, 100, 230, 280]

b_bronze = list(np.add(gold, silver))

bar1 = np.arange(len(x))
bar2 = [i+w for i in bar1]
bar3 = [i+w for i in bar2]

plt.bar(bar1, gold, w, label='Gold')
plt.bar(bar2, silver, w, label = 'Silver')
plt.bar(bar3, bronze, w, label = 'Bronze')

plt.xlabel("COuntries")
plt.ylabel("Medals")
plt.title("Medal v/s Countries")
plt.xticks(bar1+w, x)
plt.legend()
plt.show()

# %%
#Queue implementation using list | Data Structures

# %%
queue = []
def enqueue():
    element = input("Enter the element: ")
    queue.append(element)
    print(element, "is added to queue.")
    
def dequeue():
    if not queue:
        print("queue is empty.")
    else:
        e = queue.pop(0)
        print("removed element", e)
    
def display():
    print(queue)
    
while True:
    print("Select the operation 1. add 2. remove 3. show 4. quit")
    choice = int(input())
    if choice == 1:
        enqueue()
    elif choice == 2:
        dequeue()
    elif choice == 3:
        display()
    elif choice == 4:
        break
    else:
        print("Enter the correct operation.")
# Out:
# Select the operation 1. add 2. remove 3. show 4. quit
# 1
# Enter the element: 24
# 24 is added to queue.
# Select the operation 1. add 2. remove 3. show 4. quit
# 1
# Enter the element: 35
# 35 is added to queue.
# Select the operation 1. add 2. remove 3. show 4. quit
# 1
# Enter the element: 12
# 12 is added to queue.
# Select the operation 1. add 2. remove 3. show 4. quit
# 1
# Enter the element: 28
# 28 is added to queue.
# Select the operation 1. add 2. remove 3. show 4. quit
# 3
# ['24', '35', '12', '28']
# Select the operation 1. add 2. remove 3. show 4. quit
# 2
# removed element 24
# Select the operation 1. add 2. remove 3. show 4. quit
# 2
# removed element 35
# Select the operation 1. add 2. remove 3. show 4. quit
# 3
# ['12', '28']
# Select the operation 1. add 2. remove 3. show 4. quit
# 4

# %%
#Histogram | Part-1

# %%
import matplotlib.pyplot as plt

# %%
a = [1, 12, 21, 33, 44, 24, 56, 78, 50, 66, 45,
    11,96,88,33,69,77,66,77,22,55,11,22,88,66,
    44,64,34,65,83,52,56,82,38,35,36,84,15,46,
    74,35,25,36,68,65,25,35,45,65,52,85,65,14,
    35,82,62,14,22,54,65,35,36,41,65,41,67,32,
    65,14,32,95,54,52,37,48,24,35,78,14,35,65,100]

y = [1,11,21,31,41,51,61,81,91,101]

plt.hist(a, y, ec="black")

plt.xlabel("age")
plt.ylabel("count")
plt.title("Population age count")

plt.show()

# %%
a = [1, 12, 21, 33, 44, 24, 56, 78, 50, 66, 45,
    11,96,88,33,69,77,66,77,22,55,11,22,88,66,
    44,64,34,65,83,52,56,82,38,35,36,84,15,46,
    74,35,25,36,68,65,25,35,45,65,52,85,65,14,
    35,82,62,14,22,54,65,35,36,41,65,41,67,32,
    65,14,32,95,54,52,37,48,24,35,78,14,35,65,100]

plt.hist(a, 20, (0, 100), ec="black")

plt.xlabel("age")
plt.ylabel("count")
plt.title("Population age count")

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,12,22,21,20,21]

y=[1,11,21,31]
plt.hist(x,y,ec="black", weights=[2,2,2,2,2,2])

plt.xlabel("age")
plt.ylabel("count")
plt.title("Population age count")
plt.xticks(y)
plt.show()

# %%
 #Queue implementation using classes | Data structures

# %%
import collections
q = collections.deque()
q
# Out:
# deque([])

# %%
q.appendleft(21)

# %%
q.appendleft(31)

# %%
q.appendleft(41)

# %%
q
# Out:
# deque([41, 31, 21])

# %%
q.pop()
# Out:
# 21

# %%
q.pop()
# Out:
# 31

# %%
q.pop()
# Out:
# 41

# %%
import collections
q = collections.deque()

# %%
q
# Out:
# deque([])

# %%
q.append(25)

# %%
q.append(35)

# %%
q.append(45)

# %%
q
# Out:
# deque([25, 35, 45])

# %%
q.popleft()
# Out:
# 25

# %%
q.popleft()
# Out:
# 35

# %%
q.popleft()
# Out:
# 45

# %%
q.popleft()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-7d9c4e36d778> in <module>
# ----> 1 q.popleft()
#
# IndexError: pop from an empty deque

# %%
not q
# Out:
# True

# %%
q.append(45)

# %%
q.append(100)

# %%
q.append(48)

# %%
q
# Out:
# deque([45, 100, 48])

# %%
q[-1]
# Out:
# 48

# %%
q[1]
# Out:
# 100

# %%
import queue

# %%
q = queue.Queue()

# %%
q.put(10)

# %%
q.put(34)

# %%
q.put(46)

# %%
q

# %%
q.get()
# Out:
# 10

# %%
q.get()
# Out:
# 34

# %%
q.get()
# Out:
# 46

# %%
#Histogram | Part - 2

# %%
import matplotlib.pyplot as plt
a = [1,12,22,21,20,21]

y = [1,11,21,31]
plt.hist(a, y, ec="red", bottom = 10)
plt.xlabel("age")
plt.ylabel("Count")
plt.title("Population age count")
plt.xticks(y)
plt.show()

# %%
import matplotlib.pyplot as plt
a = [1,12,22,21,20,21]

y = [1,11,21,31]
plt.hist(a, y, ec="red", histtype = "step")
plt.xlabel("age")
plt.ylabel("Count")
plt.title("Population age count")
plt.xticks(y)
plt.show()

# %%
#Priority Queue | Data Strucures

# %%
q = []

# %%
q.append(10)

# %%
q.append(40)

# %%
q.sort()

# %%
q.append(20)

# %%
q.sort()

# %%
q
# Out:
# [10, 20, 40]

# %%
q.pop(0)
# Out:
# 10

# %%
q.pop(0)
# Out:
# 20

# %%
q.pop(0)
# Out:
# 40

# %%
import queue
q = queue.PriorityQueue()

# %%
q.put(10)

# %%
q.put(60)

# %%
q.put(20)

# %%
q.put(40)

# %%
q.put(40)

# %%
q.get()
# Out:
# 10

# %%
q.get()
# Out:
# 20

# %%
q.get()
# Out:
# 40

# %%
q.get()
# Out:
# 40

# %%
q.get()
# Out:
# 60

# %%
q = []

# %%
q.append((1, "alexa"))

# %%
q.append((2, "alex"))

# %%
q.append((3, "al"))

# %%
q.sort(reverse=True)

# %%
q
# Out:
# [(3, 'al'), (2, 'alex'), (1, 'alexa')]

# %%
q.pop(0)
# Out:
# (3, 'al')

# %%
q.pop(0)
# Out:
# (2, 'alex')

# %%
q.pop(0)
# Out:
# (1, 'alexa')

# %%
q.pop(0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-8689926d9981> in <module>
# ----> 1 q.pop(0)
#
# IndexError: pop from empty list

# %%
#Singly Linked List

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.ref = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    def print_LL(self):
        if self.head is None:
            print("Linked list is empty")
        else:
            n =self.head
            while n is not None:
                print(n.data)
                n = n.ref
                
LL1 = LinkedList()
LL1.print_LL()
# Out:
# Linked list is empty

# %%
#To change the color of individual Bars in Histogram | Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
a = np.random.randn(1212)

n,m, patches = plt.hist(a, bins=10)

color = ["black", "yellow", "#CCCC00", "#00FF00", "#FFFF00",
        "#00FF00", "#CCCC00", "#FFFF00", "#CCCC00", "#00FF00"]

for i in range(len(n)):
    c=color[i]
    patches[i].set_fc(c)
    
plt.xlabel("age")
plt.ylabel("people count")

plt.title("age graph")
plt.show()

# %%
#Stacked Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randn(1000, 3)

plt.hist(x, 30, histtype="barstacked") # or stacked = True

plt.xlabel("age")
plt.ylabel("count of people")
plt.title("Population count")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randn(1000)
y = np.sin(x)
z = np.cos(x)

plt.hist(x, bins="auto", ec="k")
plt.hist(y, bins="auto", ec="k")
plt.hist(z, bins="auto", ec="k")

plt.xlabel("age")
plt.ylabel("count of people")
plt.title("Population count")

plt.show()
